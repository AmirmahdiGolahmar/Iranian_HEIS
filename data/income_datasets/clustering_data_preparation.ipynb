# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('data/family_incomes_dataset_r98.csv')
df
# Out:
#            Address  Fasl      weight  khanevartype province  town  \
# 0      20001383908     2  171.199524             1  Markazi     1
# 1      20001383911     2  171.199524             1  Markazi     1
# 2      20001383915     2  171.199524             1  Markazi     1
# 3      20001383916     2  171.199524             1  Markazi     1
# 4      20001383920     2  171.199524             1  Markazi     1
# ...            ...   ...         ...           ...      ...   ...
# 18425  23006709717     3   84.791023             1   Alborz     6
# 18426  23006709720     3   84.791023             1   Alborz     6
# 18427  23006709723     3   84.791023             1   Alborz     6
# 18428  23006709807     4  254.373068             1   Alborz     6
# 18429  23006709818     4  254.373068             1   Alborz     6
#
#        Hoghugh_Income  Azad_Income  Other_Income  Yarane_Income  \
# 0                 0.0  342000000.0           0.0     21840000.0
# ...

# %%
df[['Hoghugh_Income' , 'Azad_Income' , 'Other_Income' , 'Yarane_Income' , 'total_netincome']] = df[['Hoghugh_Income' , 'Azad_Income' , 'Other_Income' , 'Yarane_Income' , 'total_netincome']] / 134607
df
# Out:
#            Address  Fasl      weight  khanevartype province  town  \
# 0      20001383908     2  171.199524             1  Markazi     1
# 1      20001383911     2  171.199524             1  Markazi     1
# 2      20001383915     2  171.199524             1  Markazi     1
# 3      20001383916     2  171.199524             1  Markazi     1
# 4      20001383920     2  171.199524             1  Markazi     1
# ...            ...   ...         ...           ...      ...   ...
# 18425  23006709717     3   84.791023             1   Alborz     6
# 18426  23006709720     3   84.791023             1   Alborz     6
# 18427  23006709723     3   84.791023             1   Alborz     6
# 18428  23006709807     4  254.373068             1   Alborz     6
# 18429  23006709818     4  254.373068             1   Alborz     6
#
#        Hoghugh_Income  Azad_Income  Other_Income  Yarane_Income  \
# 0            0.000000  2540.729680      0.000000     162.250106
# ...

# %%
df['Rural'] = 1
df.drop(columns=['weight' , 'Fasl' , 'Address'] , inplace=True)
df.head()
# Out:
#    khanevartype province  town  Hoghugh_Income  Azad_Income  Other_Income  \
# 0             1  Markazi     1        0.000000  2540.729680      0.000000
# 1             1  Markazi     1        0.000000     0.000000    319.448469
# 2             1  Markazi     1        0.000000  1593.527825      0.000000
# 3             1  Markazi     1     1755.926571     0.000000      0.000000
# 4             1  Markazi     1     1604.671377     0.000000      0.000000
#
#    Yarane_Income  total_netincome  Rural
# 0     162.250106      2702.979786      1
# 1      81.125053       400.573521      1
# 2      81.125053      1674.652878      1
# 3     162.250106      1918.176677      1
# 4     202.812632      1807.484009      1

# %%
rural98 = df.copy()

# %%
df = pd.read_csv('data/family_incomes_dataset_u98.csv')
df.head()
# Out:
#        Address  Fasl      weight  khanevartype province  town  Hoghugh_Income  \
# 0  10001000108     4  1199.12892             1  Markazi     1             0.0
# 1  10001000111     4  1199.12892             1  Markazi     1     564000000.0
# 2  10001000114     4  1199.12892             1  Markazi     1             0.0
# 3  10001000117     4  1199.12892             1  Markazi     1             0.0
# 4  10001000120     4  1199.12892             1  Markazi     1             0.0
#
#    Azad_Income  Other_Income  Yarane_Income  total_netincome
# 0          0.0   392000000.0     27300000.0      419300000.0
# 1          0.0           0.0     16380000.0      580380000.0
# 2          0.0   144000000.0      5460000.0      149460000.0
# 3          0.0   444000000.0     21840000.0      465840000.0
# 4          0.0   333000000.0     10920000.0      343920000.0

# %%
df[['Hoghugh_Income' , 'Azad_Income' , 'Other_Income' , 'Yarane_Income' , 'total_netincome']] = df[['Hoghugh_Income' , 'Azad_Income' , 'Other_Income' , 'Yarane_Income' , 'total_netincome']] / 134607
df
# Out:
#            Address  Fasl       weight  khanevartype province  town  \
# 0      10001000108     4  1199.128920             1  Markazi     1
# 1      10001000111     4  1199.128920             1  Markazi     1
# 2      10001000114     4  1199.128920             1  Markazi     1
# 3      10001000117     4  1199.128920             1  Markazi     1
# 4      10001000120     4  1199.128920             1  Markazi     1
# ...            ...   ...          ...           ...      ...   ...
# 19893  13006383810     2  2399.642385             1   Alborz     6
# 19894  13006383814     2  2399.642385             1   Alborz     6
# 19895  13006383815     2  2399.642385             1   Alborz     6
# 19896  13006383820     2  2399.642385             1   Alborz     6
# 19897  13006383823     2  2399.642385             1   Alborz     6
#
#        Hoghugh_Income  Azad_Income  Other_Income  Yarane_Income  \
# 0            0.000000     0.000000   2912.181387     202.812632
# ...

# %%
df['Rural'] = 0
df.drop(columns=['weight' , 'Fasl' , 'Address'] , inplace=True)
df.head()
# Out:
#    khanevartype province  town  Hoghugh_Income  Azad_Income  Other_Income  \
# 0             1  Markazi     1        0.000000          0.0   2912.181387
# 1             1  Markazi     1     4189.975261          0.0      0.000000
# 2             1  Markazi     1        0.000000          0.0   1069.780918
# 3             1  Markazi     1        0.000000          0.0   3298.491163
# 4             1  Markazi     1        0.000000          0.0   2473.868372
#
#    Yarane_Income  total_netincome  Rural
# 0     202.812632      3114.994020      0
# 1     121.687579      4311.662841      0
# 2      40.562526      1110.343444      0
# 3     162.250106      3460.741269      0
# 4      81.125053      2554.993425      0

# %%
urban98 = df.copy()

# %%
df = pd.read_csv('data/family_incomes_dataset_u99.csv')
df['Rural'] = 0
df.drop(columns=['weight' , 'Fasl' , 'Address'] , inplace=True)
df.head()
# Out:
#    khanevartype province  town  Hoghugh_Income  Azad_Income  Other_Income  \
# 0             1  Markazi     1     240000000.0          0.0  6.480000e+08
# 1             1  Markazi     1             0.0          0.0  6.540000e+08
# 2             1  Markazi     1     216000000.0          0.0  7.600000e+08
# 3             1  Markazi     1             0.0          0.0  1.211000e+09
# 4             1  Markazi     1             0.0          0.0  3.655000e+08
#
#    Yarane_Income  total_netincome  Rural
# 0     19390000.0     9.073900e+08      0
# 1            0.0     6.540000e+08      0
# 2            0.0     9.760000e+08      0
# 3      8470000.0     1.219470e+09      0
# 4      3010000.0     3.685100e+08      0

# %%
df[['Hoghugh_Income' , 'Azad_Income' , 'Other_Income' , 'Yarane_Income' , 'total_netincome']] = df[['Hoghugh_Income' , 'Azad_Income' , 'Other_Income' , 'Yarane_Income' , 'total_netincome']] / 236036
df
# Out:
#        khanevartype province  town  Hoghugh_Income  Azad_Income  Other_Income  \
# 0                 1  Markazi     1     1016.794048     0.000000   2745.343931
# 1                 1  Markazi     1        0.000000     0.000000   2770.763782
# 2                 1  Markazi     1      915.114644     0.000000   3219.847820
# 3                 1  Markazi     1        0.000000     0.000000   5130.573302
# 4                 1  Markazi     1        0.000000     0.000000   1548.492603
# ...             ...      ...   ...             ...          ...           ...
# 19301             1   Alborz     6     1042.100925     0.000000      0.000000
# 19302             1   Alborz     6      949.245030   889.694792    238.946601
# 19303             1   Alborz     6     1609.923910     0.000000    227.761867
# 19304             1   Alborz     6     1694.656747     0.000000    129.217577
# 19305             1   Alborz     6        0.000000     0.000000    523.225271
#
# ...

# %%
urban99 = df.copy()

# %%
df = pd.read_csv('data/family_incomes_dataset_r99.csv')
df['Rural'] = 0
df.drop(columns=['weight' , 'Fasl' , 'Address'] , inplace=True)
df.head()
# Out:
#    khanevartype province  town  Hoghugh_Income  Azad_Income  Other_Income  \
# 0             1  Markazi     1     281680008.0          0.0    30460000.0
# 1             1  Markazi     1     150000000.0  240000000.0    23760000.0
# 2             1  Markazi     1     240000000.0          0.0    42400000.0
# 3             1  Markazi     1     240000000.0          0.0    25560000.0
# 4             1  Markazi     1             0.0  150000000.0    25760000.0
#
#    Yarane_Income  total_netincome  Rural
# 0     21490000.0      333630008.0      0
# 1     21490000.0      435250000.0      0
# 2     26950000.0      309350000.0      0
# 3     21490000.0      287050000.0      0
# 4     10570000.0      186330000.0      0

# %%
df[['Hoghugh_Income' , 'Azad_Income' , 'Other_Income' , 'Yarane_Income' , 'total_netincome']] = df[['Hoghugh_Income' , 'Azad_Income' , 'Other_Income' , 'Yarane_Income' , 'total_netincome']] / 236036
df
# Out:
#        khanevartype province  town  Hoghugh_Income  Azad_Income  Other_Income  \
# 0                 1  Markazi     1     1193.377315     0.000000    129.048111
# 1                 1  Markazi     1      635.496280  1016.794048    100.662611
# 2                 1  Markazi     1     1016.794048     0.000000    179.633615
# 3                 1  Markazi     1     1016.794048     0.000000    108.288566
# 4                 1  Markazi     1        0.000000   635.496280    109.135895
# ...             ...      ...   ...             ...          ...           ...
# 18246             1   Alborz     6        0.000000  1482.824654    155.230558
# 18247             1   Alborz     6        0.000000     0.000000   1180.158959
# 18248             1   Alborz     6     2033.588097     0.000000     52.364893
# 18249             1   Alborz     6     2118.320934     0.000000    122.523683
# 18250             1   Alborz     6        0.000000  1270.992560    104.221390
#
# ...

# %%
rural99 = df.copy()

# %%
df = pd.read_csv('data/family_incomes_dataset_r1400.csv')
df['Rural'] = 1
df.drop(columns=['weight' , 'Fasl' , 'Address'] , inplace=True)
df.head()
# Out:
#    khanevartype province  town  Hoghugh_Income  Azad_Income  Other_Income  \
# 0             1  Markazi     1     354000000.0          0.0   158600000.0
# 1             1  Markazi     1             0.0  636000000.0           0.0
# 2             1  Markazi     1             0.0  173000000.0    42320000.0
# 3             1  Markazi     1     160000000.0          0.0    23560000.0
# 4             1  Markazi     1             0.0          0.0   416360000.0
#
#    Yarane_Income  total_netincome  Rural
# 0     23100000.0      535700000.0      1
# 1            0.0      636000000.0      1
# 2     17640000.0      232960000.0      1
# 3      6720000.0      190280000.0      1
# 4     10920000.0      427280000.0      1

# %%
df[['Hoghugh_Income' , 'Azad_Income' , 'Other_Income' , 'Yarane_Income' , 'total_netincome']] = df[['Hoghugh_Income' , 'Azad_Income' , 'Other_Income' , 'Yarane_Income' , 'total_netincome']] / 267272
df
# Out:
#        khanevartype province  town  Hoghugh_Income  Azad_Income  Other_Income  \
# 0                 1  Markazi     1     1324.493400     0.000000    593.402975
# 1                 1  Markazi     1        0.000000  2379.598312      0.000000
# 2                 1  Markazi     1        0.000000   647.280673    158.340567
# 3                 1  Markazi     1      598.641085     0.000000     88.149900
# 4                 1  Markazi     1        0.000000     0.000000   1557.813763
# ...             ...      ...   ...             ...          ...           ...
# 18365             1   Alborz     6        0.000000  2619.054746      7.722470
# 18366             1   Alborz     6        0.000000  1870.753390      0.000000
# 18367             1   Alborz     6        0.000000     0.000000   1870.753390
# 18368             1   Alborz     6        0.000000  2431.979407     92.041067
# 18369             1   Alborz     6     4132.120087     0.000000      0.000000
#
# ...

# %%
rural1400 = df.copy()

# %%
df = pd.read_csv('data/family_incomes_dataset_u1400.csv')
df['Rural'] = 0
df.drop(columns=['weight' , 'Fasl' , 'Address'] , inplace=True)
df.head()
# Out:
#    khanevartype province  town  Hoghugh_Income  Azad_Income  Other_Income  \
# 0             1  Markazi     1    0.000000e+00          0.0   905500000.0
# 1             1  Markazi     1    1.148000e+09          0.0   225500000.0
# 2             1  Markazi     1    0.000000e+00          0.0   594500000.0
# 3             1  Markazi     1    0.000000e+00          0.0   939500000.0
# 4             1  Markazi     1    1.200000e+08          0.0   943500000.0
#
#    Yarane_Income  total_netincome  Rural
# 0     13440000.0     9.189400e+08      0
# 1     17640000.0     1.391140e+09      0
# 2      1260000.0     5.957600e+08      0
# 3      6720000.0     9.462200e+08      0
# 4     12180000.0     1.075680e+09      0

# %%
df = pd.read_csv('data/family_incomes_dataset_u1400.csv')
df['Rural'] = 0
df.drop(columns=['weight' , 'Fasl' , 'Address'] , inplace=True)
df.head()
# Out:
#    khanevartype province  town  Hoghugh_Income  Azad_Income  Other_Income  \
# 0             1  Markazi     1    0.000000e+00          0.0   905500000.0
# 1             1  Markazi     1    1.148000e+09          0.0   225500000.0
# 2             1  Markazi     1    0.000000e+00          0.0   594500000.0
# 3             1  Markazi     1    0.000000e+00          0.0   939500000.0
# 4             1  Markazi     1    1.200000e+08          0.0   943500000.0
#
#    Yarane_Income  total_netincome  Rural
# 0     13440000.0     9.189400e+08      0
# 1     17640000.0     1.391140e+09      0
# 2      1260000.0     5.957600e+08      0
# 3      6720000.0     9.462200e+08      0
# 4     12180000.0     1.075680e+09      0

# %%
df[['Hoghugh_Income' , 'Azad_Income' , 'Other_Income' , 'Yarane_Income' , 'total_netincome']] = df[['Hoghugh_Income' , 'Azad_Income' , 'Other_Income' , 'Yarane_Income' , 'total_netincome']] / 267272
df
# Out:
#        khanevartype province  town  Hoghugh_Income  Azad_Income  Other_Income  \
# 0                 1  Markazi     1        0.000000      0.00000   3387.934389
# 1                 1  Markazi     1     4295.249783      0.00000    843.709779
# 2                 1  Markazi     1        0.000000      0.00000   2224.325780
# 3                 1  Markazi     1        0.000000      0.00000   3515.145619
# 4                 1  Markazi     1      448.980814      0.00000   3530.111647
# ...             ...      ...   ...             ...          ...           ...
# 19613             1   Alborz     6     2244.904068      0.00000    129.456135
# 19614             1   Alborz     6     1122.452034      0.00000     62.109013
# 19615             1   Alborz     6        0.000000   1870.75339     46.245024
# 19616             1   Alborz     6     2244.904068      0.00000      0.000000
# 19617             1   Alborz     6     3591.846508      0.00000   1513.813643
#
# ...

# %%
urban1400 = df.copy()

# %%
df = pd.read_csv('data/family_incomes_dataset_u1401.csv')
df['Rural'] = 0
df.drop(columns=['weight' , 'Fasl' , 'Address'] , inplace=True)
df.head()
# Out:
#    khanevartype          province  town  Hoghugh_Income  Azad_Income  \
# 0             1  AzarbaijanGharbi    16             0.0  920800000.0
# 1             1  AzarbaijanGharbi    17     840000000.0          0.0
# 2             1  AzarbaijanGharbi    17     540000000.0          0.0
# 3             1  AzarbaijanGharbi    17     672000000.0          0.0
# 4             1  AzarbaijanGharbi    17     330000000.0          0.0
#
#    Other_Income  Yarane_Income  total_netincome  Rural
# 0  9.508000e+07     17640000.0     1.033520e+09      0
# 1  4.563000e+07      6720000.0     8.923500e+08      0
# 2  8.126000e+07     17640000.0     6.389000e+08      0
# 3  6.344500e+07     12180000.0     7.476250e+08      0
# 4  1.470750e+09     23100000.0     1.823850e+09      0

# %%
df[['Hoghugh_Income' , 'Azad_Income' , 'Other_Income' , 'Yarane_Income' , 'total_netincome']] = df[['Hoghugh_Income' , 'Azad_Income' , 'Other_Income' , 'Yarane_Income' , 'total_netincome']] / 386627
df
# Out:
#        khanevartype          province  town  Hoghugh_Income  Azad_Income  \
# 0                 1  AzarbaijanGharbi    16        0.000000  2381.623632
# 1                 1  AzarbaijanGharbi    17     2172.636676     0.000000
# 2                 1  AzarbaijanGharbi    17     1396.695006     0.000000
# 3                 1  AzarbaijanGharbi    17     1738.109341     0.000000
# 4                 1  AzarbaijanGharbi    17      853.535837     0.000000
# ...             ...               ...   ...             ...          ...
# 19562             1            Alborz     6     2052.624364     0.000000
# 19563             1            Alborz     6     2714.761256     0.000000
# 19564             1            Alborz     6     1862.260008     0.000000
# 19565             1            Alborz     6     4001.789836     0.000000
# 19566             1            Alborz     6        0.000000  2327.825010
#
#        Other_Income  Yarane_Income  total_netincome  Rural
# ...

# %%
urban1401 = df.copy()

# %%
df = pd.read_csv('data/family_incomes_dataset_r1401.csv')
df['Rural'] = 1
df.drop(columns=['weight' , 'Fasl' , 'Address'] , inplace=True)
df.head()
# Out:
#    khanevartype        province  town  Hoghugh_Income  Azad_Income  \
# 0             1  KhorasanRazavi    16     384000000.0          0.0
# 1             1  KhorasanRazavi    16     340000000.0          0.0
# 2             1  KhorasanRazavi    16     624000000.0          0.0
# 3             1  KhorasanRazavi    16             0.0          0.0
# 4             1  KhorasanRazavi    16     600000000.0          0.0
#
#    Other_Income  Yarane_Income  total_netincome  Rural
# 0    53200000.0     18220000.0      455420000.0      1
# 1    10300000.0      9100000.0      359400000.0      1
# 2    16560000.0     16380000.0      656940000.0      1
# 3    70640000.0     21840000.0       92480000.0      1
# 4    42570000.0     20020000.0      662590000.0      1

# %%
df[['Hoghugh_Income' , 'Azad_Income' , 'Other_Income' , 'Yarane_Income' , 'total_netincome']] = df[['Hoghugh_Income' , 'Azad_Income' , 'Other_Income' , 'Yarane_Income' , 'total_netincome']] / 386627
df
# Out:
#        khanevartype        province  town  Hoghugh_Income  Azad_Income  \
# 0                 1  KhorasanRazavi    16      993.205337     0.000000
# 1                 1  KhorasanRazavi    16      879.400559     0.000000
# 2                 1  KhorasanRazavi    16     1613.958673     0.000000
# 3                 1  KhorasanRazavi    16        0.000000     0.000000
# 4                 1  KhorasanRazavi    16     1551.883340     0.000000
# ...             ...             ...   ...             ...          ...
# 18379             1  KhorasanRazavi     6     1337.206144     0.000000
# 18380             1  KhorasanRazavi     6        0.000000  1551.883340
# 18381             1  KhorasanRazavi     6        0.000000  1293.236116
# 18382             1  KhorasanRazavi    16        0.000000  1836.395285
# 18383             1  KhorasanRazavi    16        0.000000     0.000000
#
#        Other_Income  Yarane_Income  total_netincome  Rural
# ...

# %%
rural1401 = df.copy()

# %%
df = pd.concat([rural98 , rural99 , rural1400 , urban98 , urban99 , urban1400 , urban1401 , rural1401] ,axis=0)
df
# Out:
#        khanevartype        province  town  Hoghugh_Income  Azad_Income  \
# 0                 1         Markazi     1        0.000000  2540.729680
# 1                 1         Markazi     1        0.000000     0.000000
# 2                 1         Markazi     1        0.000000  1593.527825
# 3                 1         Markazi     1     1755.926571     0.000000
# 4                 1         Markazi     1     1604.671377     0.000000
# ...             ...             ...   ...             ...          ...
# 18379             1  KhorasanRazavi     6     1337.206144     0.000000
# 18380             1  KhorasanRazavi     6        0.000000  1551.883340
# 18381             1  KhorasanRazavi     6        0.000000  1293.236116
# 18382             1  KhorasanRazavi    16        0.000000  1836.395285
# 18383             1  KhorasanRazavi    16        0.000000     0.000000
#
#        Other_Income  Yarane_Income  total_netincome  Rural
# ...

# %%
le = LabelEncoder()
df.province = le.fit_transform(df['province'])
df.head()
# Out:
#    khanevartype  province  town  Hoghugh_Income  Azad_Income  Other_Income  \
# 0             1        22     1        0.000000  2540.729680      0.000000
# 1             1        22     1        0.000000     0.000000    319.448469
# 2             1        22     1        0.000000  1593.527825      0.000000
# 3             1        22     1     1755.926571     0.000000      0.000000
# 4             1        22     1     1604.671377     0.000000      0.000000
#
#    Yarane_Income  total_netincome  Rural
# 0     162.250106      2702.979786      1
# 1      81.125053       400.573521      1
# 2      81.125053      1674.652878      1
# 3     162.250106      1918.176677      1
# 4     202.812632      1807.484009      1

# %%
df = df.apply(lambda x : (x - x.mean()) / x.std())
df.head()
# Out:
#    khanevartype  province     town  Hoghugh_Income  Azad_Income  Other_Income  \
# 0     -0.025154  0.775825 -0.97867       -0.656218     1.187685     -0.596674
# 1     -0.025154  0.775825 -0.97867       -0.656218    -0.349396     -0.293301
# 2     -0.025154  0.775825 -0.97867       -0.656218     0.614651     -0.596674
# 3     -0.025154  0.775825 -0.97867        0.736282    -0.349396     -0.596674
# 4     -0.025154  0.775825 -0.97867        0.616332    -0.349396     -0.596674
#
#    Yarane_Income  total_netincome     Rural
# 0       1.585545         0.294224  1.323337
# 1       0.193085        -0.835206  1.323337
# 2       0.193085        -0.210215  1.323337
# 3       1.585545        -0.090756  1.323337
# 4       2.281775        -0.145055  1.323337

# %%
df.to_csv('data/clustering_data.csv')
